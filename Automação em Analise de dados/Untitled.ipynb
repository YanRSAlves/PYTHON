# %% [markdown]
# # Aplicando o pyautogui

# %%
import pyautogui
import pyperclip
import time


pyautogui.PAUSE = 1


pyautogui.hotkey("ctrl","t")
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)

pyautogui.click(x=369, y=293, clicks=2)
time.sleep(2)

pyautogui.click(x=416, y=484, button="right")
pyautogui.click(x=528, y=644)

time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\alves\Desktop\Desenvolvendo o Python no jupyter\Untitled.ipynb Célula: 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alves/Desktop/Desenvolvendo%20o%20Python%20no%20jupyter/Untitled.ipynb#ch0000001?line=0'>1</a> import pyautogui
#       <a href='vscode-notebook-cell:/c%3A/Users/alves/Desktop/Desenvolvendo%20o%20Python%20no%20jupyter/Untitled.ipynb#ch0000001?line=1'>2</a> import pyperclip
#       <a href='vscode-notebook-cell:/c%3A/Users/alves/Desktop/Desenvolvendo%20o%20Python%20no%20jupyter/Untitled.ipynb#ch0000001?line=2'>3</a> import time
#
# ModuleNotFoundError: No module named 'pyautogui'

# %%
import pandas

tabela = pandas.read_excel((r"C:\Users\alves\Downloads\Vendas - Dez.xlsx"))
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
quantidade = tabela["Quantidade"].sum()
faturamento = tabela["Valor Final"].sum()

print(quantidade)
print(faturamento)
# Out:
# 15227
# 2917311

# %%
pyautogui.hotkey("ctrl","t")
pyperclip.copy("https://mail.google.com/mail/u/0/?pli=1#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(7)

pyautogui.click(x=106, y=205)
pyautogui.write("alvesyan914@gmail.com")
pyautogui.press("tab")
pyautogui.write("nem0tente0@gmail.com")
pyautogui.press("tab")
pyautogui.write("hahshhjxjdjdj@gmail.com")
pyautogui.press("tab")
pyautogui.write("conta05598ff@gmail.com")
pyautogui.press("tab")
pyautogui.press("tab")

#Escrevendo o assunto
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")

texto = f"""

Prezados, bom dia estou enviando o 
nosso faturamento mensal para análise.

Faturamento Mensal: R${faturamento:,.2f}
Quantidade de produtos vendidos: {quantidade:,}

abs!
Yan Alves
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("ctrl", "enter")

# %%
time.sleep(5)
pyautogui.position()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alves\Desktop\Desenvolvendo o Python no jupyter\Untitled.ipynb Célula: 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alves/Desktop/Desenvolvendo%20o%20Python%20no%20jupyter/Untitled.ipynb#ch0000008?line=0'>1</a> time.sleep(5)
#       <a href='vscode-notebook-cell:/c%3A/Users/alves/Desktop/Desenvolvendo%20o%20Python%20no%20jupyter/Untitled.ipynb#ch0000008?line=1'>2</a> pyautogui.position()
#
# NameError: name 'time' is not defined
